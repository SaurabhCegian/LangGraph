# %%
from typing import List, TypedDict
from langgraph.graph import StateGraph

# %%
class AgentState(TypedDict):
  values : List[int]
  name : str
  result : str

# %%
def process_value(state : AgentState) -> AgentState:
  state['result'] = f"Hi {state['name']} and your result is {sum(state['values'])}"
  return state

# %%
graph = StateGraph(AgentState)
graph.add_node("processor", process_value)
graph.set_entry_point("processor")
graph.set_finish_point("processor")

app = graph.compile()
answer = app.invoke({"values":[1,2,3,4], "name": "Saurabh"})
print(answer["result"])
# Out:
# Hi Saurabh and your result is 10
